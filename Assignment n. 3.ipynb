# %%
import pandas as pd

# %%
data = pd.read_csv('./okcupid_profiles.csv')

# %%
data
# Out:
#        age     status sex orientation       body_type               diet  \
# 0       22     single   m    straight  a little extra  strictly anything
# 1       35     single   m    straight         average       mostly other
# 2       38  available   m    straight            thin           anything
# 3       23     single   m    straight            thin         vegetarian
# 4       29     single   m    straight        athletic                NaN
# ...    ...        ...  ..         ...             ...                ...
# 59941   59     single   f    straight             NaN                NaN
# 59942   24     single   m    straight             fit    mostly anything
# 59943   42     single   m    straight         average    mostly anything
# 59944   27     single   m    straight        athletic    mostly anything
# 59945   39     single   m         gay         average                NaN
#
#            drinks      drugs                          education  \
# ...

# %% [markdown]
# Data Analysis of users' profiles on dating app OkCupid

# %%
data.head(5)
# Out:
#    age     status sex orientation       body_type               diet  \
# 0   22     single   m    straight  a little extra  strictly anything
# 1   35     single   m    straight         average       mostly other
# 2   38  available   m    straight            thin           anything
# 3   23     single   m    straight            thin         vegetarian
# 4   29     single   m    straight        athletic                NaN
#
#      drinks      drugs                          education  \
# 0  socially      never      working on college/university
# 1     often  sometimes              working on space camp
# 2  socially        NaN     graduated from masters program
# 3  socially        NaN      working on college/university
# 4  socially      never  graduated from college/university
#
#              ethnicity  ...  \
# 0         asian, white  ...
# 1                white  ...
# 2                  NaN  ...
# 3                white  ...
# 4  asian, black, other  ...
#
# ...

# %%
data.query('sex == "f"')
# Out:
#        age  status sex orientation body_type               diet    drinks  \
# 6       32  single   f    straight       fit  strictly anything  socially
# 7       31  single   f    straight   average    mostly anything  socially
# 8       24  single   f    straight       NaN  strictly anything  socially
# 13      30  single   f    straight    skinny    mostly anything  socially
# 14      29  single   f    straight      thin    mostly anything  socially
# ...    ...     ...  ..         ...       ...                ...       ...
# 59934   43  single   f    straight   average           anything  socially
# 59935   33  single   f    straight     curvy           anything  socially
# 59936   25  single   f    straight   average    mostly anything  socially
# 59940   31  single   f    straight       NaN                NaN  socially
# 59941   59  single   f    straight       NaN                NaN  socially
#
#        drugs                          education                ethnicity  ...  \
# ...

# %%
data.query('sex == "f"' and 'status == "single"').count()
# Out:
# age            55697
# status         55697
# sex            55697
# orientation    55697
# body_type      51057
# diet           33420
# drinks         52850
# drugs          42697
# education      49510
# ethnicity      50537
# height         55694
# income         55697
# job            48033
# last_online    55697
# location       55697
# offspring      22858
# pets           36799
# religion       36471
# sign           45313
# smokes         50459
# speaks         55650
# essay0         50466
# essay1         48546
# essay2         46568
# essay3         44866
# essay4         45743
# essay5         45523
# essay6         42664
# essay7         44003
# essay8         37448
# essay9         43687
# dtype: int64

# %% [markdown]
# Looking for missing values

# %%
data.isna().sum()
# Out:
# age                0
# status             0
# sex                0
# orientation        0
# body_type       5296
# diet           24395
# drinks          2985
# drugs          14080
# education       6628
# ethnicity       5680
# height             3
# income             0
# job             8198
# last_online        0
# location           0
# offspring      35561
# pets           19921
# religion       20226
# sign           11056
# smokes          5512
# speaks            50
# essay0          5488
# essay1          7572
# essay2          9638
# essay3         11476
# essay4         10537
# essay5         10850
# essay6         13771
# essay7         12451
# essay8         19225
# essay9         12603
# dtype: int64

# %%
data.query('sex == "f"' and 'status == "single"').mean()
# Out:
# /var/folders/n2/w8qr7mt13pz1cdd560k6hl8h0000gn/T/ipykernel_1184/3927967778.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.query('sex == "f"' and 'status == "single"').mean()
# age          32.371223
# height       68.290714
# income    19605.809433
# dtype: float64

# %%
data.query('sex == "f"' and 'status == "available"').mean()
# Out:
# /var/folders/n2/w8qr7mt13pz1cdd560k6hl8h0000gn/T/ipykernel_1184/2551827234.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   data.query('sex == "f"' and 'status == "available"').mean()
# age          33.869169
# height       68.838606
# income    27859.840751
# dtype: float64

# %% [markdown]
# Single and available female users have quite a large gap in terms of average income

# %%
data.describe()
# Out:
#                 age        height          income
# count  59946.000000  59943.000000    59946.000000
# mean      32.340290     68.295281    20033.222534
# std        9.452779      3.994803    97346.192104
# min       18.000000      1.000000       -1.000000
# 25%       26.000000     66.000000       -1.000000
# 50%       30.000000     68.000000       -1.000000
# 75%       37.000000     71.000000       -1.000000
# max      110.000000     95.000000  1000000.000000

# %% [markdown]
# On average the age of a user of the app is 32 years old, with an income around 20.000$ (but stardard deviation is high, so it's difficult to say)

# %%
data.corr().style.background_gradient()
# Out:
# <style type="text/css">
# #T_a0fef_row0_col0, #T_a0fef_row1_col1, #T_a0fef_row2_col2 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_a0fef_row0_col1, #T_a0fef_row0_col2, #T_a0fef_row1_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_a0fef_row1_col2 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_a0fef_row2_col0 {
#   background-color: #fcf4fa;
#   color: #000000;
# }
# #T_a0fef_row2_col1 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# </style>
# <table id="T_a0fef">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a0fef_level0_col0" class="col_heading level0 col0" >age</th>
#       <th id="T_a0fef_level0_col1" class="col_heading level0 col1" >height</th>
#       <th id="T_a0fef_level0_col2" class="col_heading level0 col2" >income</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a0fef_level0_row0" class="row_heading level0 row0" >age</th>
# ...

# %% [markdown]
# No relevant correlation between age, height and income

# %%
data.query('age>= "30"' and 'sex == "m"')['status == "available"'].count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/core/indexes/base.py:3621, in Index.get_loc(self, key, method, tolerance)
#    3620 try:
# -> 3621     return self._engine.get_loc(casted_key)
#    3622 except KeyError as err:
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:136, in pandas._libs.index.IndexEngine.get_loc()
#
# File ~/opt/anaconda3/lib/python3.9/site-packages/pandas/_libs/index.pyx:163, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/hashtable_class_helper.pxi:5198, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas/_libs/hashtable_class_helper.pxi:5206, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'status == "available"'
#
# The above exception was the direct cause of the following exception:
#
# ...

# %% [markdown]
# I wanted to count the male users with an age >= 30 and still single, but didn't manage

# %%
age = pd.cut(data['age'], [0, 10, 30, 60, 80])
result = data.pivot_table(index = ['sex', age], columns = ['income'])
print(result)
# Out:
#                     age                                              \
# income         -1          20000      30000      40000      50000
# sex age
# f   (10, 30]  25.553221  23.955607  25.694737  26.613497  26.990826
#     (30, 60]  39.332314  38.994083  38.491667  38.668675  40.000000
#     (60, 80]  63.763098  65.166667  64.500000  64.500000  64.100000
# m   (10, 30]  25.808065  24.068049  25.736287  26.049869  26.482650
#     (30, 60]  38.722462  37.874659  39.170732  37.536232  39.577039
#     (60, 80]  63.954407  64.818182  64.500000  63.777778  64.500000
#
#                                                                      ...  \
# income          60000      70000      80000      100000     150000   ...
# sex age                                                              ...
# f   (10, 30]  27.046875  25.902439  27.500000  27.906250  27.166667  ...
#     (30, 60]  39.839161  42.982906  41.415385  41.455814  40.406780  ...
# ...
